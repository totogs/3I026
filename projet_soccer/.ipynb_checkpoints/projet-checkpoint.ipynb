# %% [markdown]
# **Indiquer dans la boîte ci-dessous vos noms et prénoms**

# %% [markdown]
# Dousble-cliquer ici et remplacer par les noms et prénoms de votre binôme

# %% [markdown]
# # 3I026 - Intelligence artificielle & Data science
#
# # Projet

# %% [markdown]
# ## Données
#
# Vous devez travailler sur les données du projet Kaggle *European Soccer Database* accessible à l'adresse https://www.kaggle.com/hugomathien/soccer.
#
# Les données en version SQLite sur la page http://www-connex.lip6.fr/~schwander/3I026/soccer.zip ou en version CSV http://www-connex.lip6.fr/~denoyer/wordpress/wp-content/uploads/2018/01/soccer.tar.gz. Pour facilter le travail dans les salles de la PPTI (et éviter de dépasser le quota de votre home), les données sont accessibles aussi dans `/Vrac/3I026/soccer/`.
#
# Quel que soit le moyen pour récupérer le fichier de données, il est indispensable de lire en détail la page Kaggle pour comprendre à quoi ces données correspondent.
#
# **Rappel:** il est attendu un notebook Python par problème, et le problème étudié doit être décrit précisément. Votre rapport devra impérativement suivre le format suivant.

# %% [markdown]
# ## Partie 1 - Description du problème

# %% [markdown]
# Le but de ce projet est de déterminer le résultat d'un match de champions league.
# Nous avons à notre disposition les données des match de ligue des 11 pays qui participe à la champion's league depuis 2008, les données des équipes et leurs caractéristiques et les données des joueurs et leurs caractéristiques.
# Pour procéder à notre programme de prédiction nous avons pensés à utiliser un labelset incluant le score, les joueurs et leur potentiel, le potentiel des équipes et les

# %% [markdown]
# ## Partie 2 - Modèle

# %%
import sqlite3
import pandas as pd
import numpy as np

conn = sqlite3.connect("database.sqlite")
conn.row_factory = sqlite3.Row

c = conn.cursor()
#Importation des données
teams = pd.read_sql_query("Select * from Team", conn)
team_attributes = pd.read_sql_query("Select * from Team_Attributes", conn)
countries = pd.read_sql_query("Select * from Country", conn)
league = pd.read_sql_query("Select * from League", conn)
match = pd.read_sql_query("Select * from Match", conn)
players = pd.read_sql_query("Select * from Player", conn)
player_attributes = pd.read_sql_query("Select * from Player_attributes", conn)

conn.close()

# %%
#Affichage des données des équipes 
teams.head(5)
# Out:
#    id  team_api_id  team_fifa_api_id     team_long_name team_short_name
# 0   1         9987             673.0           KRC Genk             GEN
# 1   2         9993             675.0       Beerschot AC             BAC
# 2   3        10000           15005.0   SV Zulte-Waregem             ZUL
# 3   4         9994            2007.0   Sporting Lokeren             LOK
# 4   5         9984            1750.0  KSV Cercle Brugge             CEB

# %%
#Affichage des attributs de jeux des équipes
team_attributes.head(5)
# Out:
#    id  team_fifa_api_id  team_api_id                 date  buildUpPlaySpeed  \
# 0   1               434         9930  2010-02-22 00:00:00                60
# 1   2               434         9930  2014-09-19 00:00:00                52
# 2   3               434         9930  2015-09-10 00:00:00                47
# 3   4                77         8485  2010-02-22 00:00:00                70
# 4   5                77         8485  2011-02-22 00:00:00                47
#
#   buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# 0              Balanced                   NaN                    Little
# 1              Balanced                  48.0                    Normal
# 2              Balanced                  41.0                    Normal
# 3                  Fast                   NaN                    Little
# 4              Balanced                   NaN                    Little
#
#    buildUpPlayPassing buildUpPlayPassingClass           ...             \
# 0                  50                   Mixed           ...
# 1                  56                   Mixed           ...
# 2                  54                   Mixed           ...
# 3                  70                    Long           ...
# 4                  52                   Mixed           ...
#
#   chanceCreationShooting  chanceCreationShootingClass  \
# 0                     55                       Normal
# 1                     64                       Normal
# 2                     64                       Normal
# 3                     70                         Lots
# 4                     52                       Normal
#
#   chanceCreationPositioningClass  defencePressure defencePressureClass  \
# 0                      Organised               50               Medium
# 1                      Organised               47               Medium
# 2                      Organised               47               Medium
# 3                      Organised               60               Medium
# 4                      Organised               47               Medium
#
#    defenceAggression defenceAggressionClass defenceTeamWidth  \
# 0                 55                  Press               45
# 1                 44                  Press               54
# 2                 44                  Press               54
# 3                 70                 Double               70
# 4                 47                  Press               52
#
#    defenceTeamWidthClass defenceDefenderLineClass
# 0                 Normal                    Cover
# 1                 Normal                    Cover
# 2                 Normal                    Cover
# 3                   Wide                    Cover
# 4                 Normal                    Cover
#
# [5 rows x 25 columns]

# %%
#Affichage des statistiques des attributs de jeux des équipes
team_attributes.describe()
# Out:
#                 id  team_fifa_api_id    team_api_id  buildUpPlaySpeed  \
# count  1458.000000       1458.000000    1458.000000       1458.000000
# mean    729.500000      17706.982167    9995.727023         52.462277
# std     421.032659      39179.857739   13264.869900         11.545869
# min       1.000000          1.000000    1601.000000         20.000000
# 25%     365.250000        110.000000    8457.750000         45.000000
# 50%     729.500000        485.000000    8674.000000         52.000000
# 75%    1093.750000       1900.000000    9904.000000         62.000000
# max    1458.000000     112513.000000  274581.000000         80.000000
#
#        buildUpPlayDribbling  buildUpPlayPassing  chanceCreationPassing  \
# count            489.000000         1458.000000            1458.000000
# mean              48.607362           48.490398              52.165295
# std                9.678290           10.896101              10.360793
# min               24.000000           20.000000              21.000000
# 25%               42.000000           40.000000              46.000000
# 50%               49.000000           50.000000              52.000000
# 75%               55.000000           55.000000              59.000000
# max               77.000000           80.000000              80.000000
#
#        chanceCreationCrossing  chanceCreationShooting  defencePressure  \
# count             1458.000000             1458.000000      1458.000000
# mean                53.731824               53.969136        46.017147
# std                 11.086796               10.327566        10.227225
# min                 20.000000               22.000000        23.000000
# 25%                 47.000000               48.000000        39.000000
# 50%                 53.000000               53.000000        45.000000
# 75%                 62.000000               61.000000        51.000000
# max                 80.000000               80.000000        72.000000
#
#        defenceAggression  defenceTeamWidth
# count        1458.000000       1458.000000
# mean           49.251029         52.185871
# std             9.738028          9.574712
# min            24.000000         29.000000
# 25%            44.000000         47.000000
# 50%            48.000000         52.000000
# 75%            55.000000         58.000000
# max            72.000000         73.000000

# %%
#Affichage des données des pays
countries
# Out:
#        id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland

# %%
#Affichge des données des ligues
league
# Out:
#        id  country_id                      name
# 0       1           1    Belgium Jupiler League
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 3    7809        7809     Germany 1. Bundesliga
# 4   10257       10257             Italy Serie A
# 5   13274       13274    Netherlands Eredivisie
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League

# %%
#affichage des données des matchs
match.head(5)
# Out:
#    id  country_id  league_id     season  stage                 date  \
# 0   1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1   2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2   3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3   4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4   5           1          1  2008/2009      1  2008-08-16 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...   \
# 0        492473              9987              9993               1  ...
# 1        492474             10000              9994               0  ...
# 2        492475              9984              8635               0  ...
# 3        492476              9991              9998               5  ...
# 4        492477              7947              9985               1  ...
#
#     SJA   VCH   VCD   VCA   GBH   GBD   GBA   BSH   BSD   BSA
# 0  4.00  1.65  3.40  4.50  1.78  3.25  4.00  1.73  3.40  4.20
# 1  3.80  2.00  3.25  3.25  1.85  3.25  3.75  1.91  3.25  3.60
# 2  2.50  2.35  3.25  2.65  2.50  3.20  2.50  2.30  3.20  2.75
# 3  7.50  1.45  3.75  6.50  1.50  3.75  5.50  1.44  3.75  6.50
# 4  1.73  4.50  3.40  1.65  4.50  3.50  1.65  4.75  3.30  1.67
#
# [5 rows x 115 columns]

# %%
#Affichage des données des joueurs
players.head(5)
# Out:
#    id  player_api_id         player_name  player_fifa_api_id  \
# 0   1         505942  Aaron Appindangoye              218353
# 1   2         155782     Aaron Cresswell              189615
# 2   3         162549         Aaron Doran              186170
# 3   4          30572       Aaron Galindo              140161
# 4   5          23780        Aaron Hughes               17725
#
#               birthday  height  weight
# 0  1992-02-29 00:00:00  182.88     187
# 1  1989-12-15 00:00:00  170.18     146
# 2  1991-05-13 00:00:00  170.18     163
# 3  1982-05-08 00:00:00  182.88     198
# 4  1979-11-08 00:00:00  182.88     154

# %%
#Affichage des attributs de jeux des joueurs
player_attributes.head(5)
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
# 3   4              218353         505942  2015-03-20 00:00:00            61.0
# 4   5              218353         505942  2007-02-22 00:00:00            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
#       ...       vision  penalties  marking  standing_tackle  sliding_tackle  \
# 0     ...         54.0       48.0     65.0             69.0            69.0
# 1     ...         54.0       48.0     65.0             69.0            69.0
# 2     ...         54.0       48.0     65.0             66.0            69.0
# 3     ...         53.0       47.0     62.0             63.0            66.0
# 4     ...         53.0       47.0     62.0             63.0            66.0
#
#    gk_diving  gk_handling  gk_kicking  gk_positioning  gk_reflexes
# 0        6.0         11.0        10.0             8.0          8.0
# 1        6.0         11.0        10.0             8.0          8.0
# 2        6.0         11.0        10.0             8.0          8.0
# 3        5.0         10.0         9.0             7.0          7.0
# 4        5.0         10.0         9.0             7.0          7.0
#
# [5 rows x 42 columns]

# %%
#Affichage des statistiques des attributs de jeux des joueurs
player_attributes.describe()
# Out:
#                  id  player_fifa_api_id  player_api_id  overall_rating  \
# count  183978.00000       183978.000000  183978.000000   183142.000000
# mean    91989.50000       165671.524291  135900.617324       68.600015
# std     53110.01825        53851.094769  136927.840510        7.041139
# min         1.00000            2.000000    2625.000000       33.000000
# 25%     45995.25000       155798.000000   34763.000000       64.000000
# 50%     91989.50000       183488.000000   77741.000000       69.000000
# 75%    137983.75000       199848.000000  191080.000000       73.000000
# max    183978.00000       234141.000000  750584.000000       94.000000
#
#            potential       crossing      finishing  heading_accuracy  \
# count  183142.000000  183142.000000  183142.000000     183142.000000
# mean       73.460353      55.086883      49.921078         57.266023
# std         6.592271      17.242135      19.038705         16.488905
# min        39.000000       1.000000       1.000000          1.000000
# 25%        69.000000      45.000000      34.000000         49.000000
# 50%        74.000000      59.000000      53.000000         60.000000
# 75%        78.000000      68.000000      65.000000         68.000000
# max        97.000000      95.000000      97.000000         98.000000
#
#        short_passing        volleys      ...               vision  \
# count  183142.000000  181265.000000      ...        181265.000000
# mean       62.429672      49.468436      ...            57.873550
# std        14.194068      18.256618      ...            15.144086
# min         3.000000       1.000000      ...             1.000000
# 25%        57.000000      35.000000      ...            49.000000
# 50%        65.000000      52.000000      ...            60.000000
# 75%        72.000000      64.000000      ...            69.000000
# max        97.000000      93.000000      ...            97.000000
#
#            penalties        marking  standing_tackle  sliding_tackle  \
# count  183142.000000  183142.000000    183142.000000   181265.000000
# mean       55.003986      46.772242        50.351257       48.001462
# std        15.546519      21.227667        21.483706       21.598778
# min         2.000000       1.000000         1.000000        2.000000
# 25%        45.000000      25.000000        29.000000       25.000000
# 50%        57.000000      50.000000        56.000000       53.000000
# 75%        67.000000      66.000000        69.000000       67.000000
# max        96.000000      96.000000        95.000000       95.000000
#
#            gk_diving    gk_handling     gk_kicking  gk_positioning  \
# count  183142.000000  183142.000000  183142.000000   183142.000000
# mean       14.704393      16.063612      20.998362       16.132154
# std        16.865467      15.867382      21.452980       16.099175
# min         1.000000       1.000000       1.000000        1.000000
# 25%         7.000000       8.000000       8.000000        8.000000
# 50%        10.000000      11.000000      12.000000       11.000000
# 75%        13.000000      15.000000      15.000000       15.000000
# max        94.000000      93.000000      97.000000       96.000000
#
#          gk_reflexes
# count  183142.000000
# mean       16.441439
# std        17.198155
# min         1.000000
# 25%         8.000000
# 50%        11.000000
# 75%        15.000000
# max        96.000000
#
# [8 rows x 38 columns]

# %%
match_stat=match.copy()
#Récupération des colonnes représentant les nombres de buts de chaque équipe dans un match
match_stat=match_stat[["league_id","match_api_id", "home_team_api_id", "away_team_api_id", "home_team_goal", "away_team_goal"]]
match_stat.head(5)
# Out:
#    league_id  match_api_id  home_team_api_id  away_team_api_id  \
# 0          1        492473              9987              9993
# 1          1        492474             10000              9994
# 2          1        492475              9984              8635
# 3          1        492476              9991              9998
# 4          1        492477              7947              9985
#
#    home_team_goal  away_team_goal
# 0               1               1
# 1               0               0
# 2               0               3
# 3               5               0
# 4               1               3

# %% [markdown]
# On veut déterminer la moyenne de but à domicile et en extérieur de chaque équipe et aussi déterminer la moyenne de but encaisser à domicile et en extérieur pour pouvoir calculer un ratio de victoire

# %%
team_match_stat=teams.copy()
#On groupe les données des match par numéro d'équipe à domicile et en extérieur et on calcul la moyenne
home_stat = match_stat.groupby("home_team_api_id").mean()[["league_id", "home_team_goal", "away_team_goal"]].reset_index()
away_stat = match_stat.groupby("away_team_api_id").mean()[[ "home_team_goal", "away_team_goal"]].reset_index()

#On calcul le ratio moyenne de but mis moins moyenne de but encaisser à domicile
home = home_stat["home_team_goal"].values
away = home_stat["away_team_goal"].values
ratio = (home-away)
home_stat["ratio_home"]=pd.Series(ratio)
home_stat = home_stat.drop("away_team_goal",1)

#On calcul le ratio moyenne de but mis moins moyenne de but encaisser en extérieur
home = away_stat["home_team_goal"].values
away = away_stat["away_team_goal"].values
ratio = (away-home)
away_stat["ratio_away"]=pd.Series(ratio)
away_stat = away_stat.drop("home_team_goal",1)

# %%
team_match_stat = team_match_stat.merge(home_stat, left_on="team_api_id", right_on="home_team_api_id")
team_match_stat = team_match_stat.merge(away_stat, left_on="team_api_id", right_on="away_team_api_id")
team_match_stat = team_match_stat.drop("home_team_api_id",1)
team_match_stat = team_match_stat.drop("away_team_api_id",1)
team_match_stat.head(5)
# Out:
#    id  team_api_id  team_fifa_api_id     team_long_name team_short_name  \
# 0   1         9987             673.0           KRC Genk             GEN
# 1   2         9993             675.0       Beerschot AC             BAC
# 2   3        10000           15005.0   SV Zulte-Waregem             ZUL
# 3   4         9994            2007.0   Sporting Lokeren             LOK
# 4   5         9984            1750.0  KSV Cercle Brugge             CEB
#
#    league_id  home_team_goal  ratio_home  away_team_goal  ratio_away
# 0        1.0        1.933962    0.933962        1.349057   -0.018868
# 1        1.0        1.473684    0.184211        0.815789   -1.013158
# 2        1.0        1.660377    0.386792        1.226415   -0.141509
# 3        1.0        1.405660    0.245283        1.226415   -0.179245
# 4        1.0        1.307692    0.021978        1.032967   -0.692308

# %%
#Calcul de la moyenne de but globale (domicile et extérieur)
home = team_match_stat["home_team_goal"].values
away = team_match_stat["away_team_goal"].values
goal_rate = (home+away)/2

team_match_stat["goal_rate"]=pd.Series(goal_rate)


#calcul du ratio global
home_ratio = team_match_stat["ratio_home"].values
away_ratio = team_match_stat["ratio_away"].values
goal_rate = (home_ratio+away_ratio)/2

team_match_stat["ratio"]=pd.Series(goal_rate)

team_match_stat.head(5)
# Out:
#    id  team_api_id  team_fifa_api_id     team_long_name team_short_name  \
# 0   1         9987             673.0           KRC Genk             GEN
# 1   2         9993             675.0       Beerschot AC             BAC
# 2   3        10000           15005.0   SV Zulte-Waregem             ZUL
# 3   4         9994            2007.0   Sporting Lokeren             LOK
# 4   5         9984            1750.0  KSV Cercle Brugge             CEB
#
#    league_id  home_team_goal  ratio_home  away_team_goal  ratio_away  \
# 0        1.0        1.933962    0.933962        1.349057   -0.018868
# 1        1.0        1.473684    0.184211        0.815789   -1.013158
# 2        1.0        1.660377    0.386792        1.226415   -0.141509
# 3        1.0        1.405660    0.245283        1.226415   -0.179245
# 4        1.0        1.307692    0.021978        1.032967   -0.692308
#
#    goal_rate     ratio
# 0   1.641509  0.457547
# 1   1.144737 -0.414474
# 2   1.443396  0.122642
# 3   1.316038  0.033019
# 4   1.170330 -0.335165

# %%
#On trie selon le ratio global et on affiche les données
team_match_stat = team_match_stat.sort_values(["ratio"], ascending=[0])
team_match_stat.tail(50)
# Out:
#         id  team_api_id  team_fifa_api_id            team_long_name  \
# 111  15634         9911             160.0                VfL Bochum
# 110  15633         8295            1832.0             Karlsruher SC
# 20    1042         6351            2013.0                 KAS Eupen
# 225  36723         4064               NaN                  Feirense
# 147  22042         9880          110915.0                    Cesena
# 50    5747        10172              15.0       Queens Park Rangers
# 271  43800         9868            1742.0      Xerez Club Deportivo
# 46    4225         8602             110.0   Wolverhampton Wanderers
# 37    3469         8549              12.0             Middlesbrough
# 189  31451         8244             301.0               Widzew Łódź
# 91   14106         8550              68.0                   FC Metz
# 53    6509         9798            1793.0                   Reading
# 297  50204         7730            1862.0        FC Lausanne-Sports
# 104  15627         9912             159.0     DSC Arminia Bielefeld
# 106  15629         8398             162.0        FC Energie Cottbus
# 179  29624         6433          100632.0           Go Ahead Eagles
# 298  51606         7896               NaN                    Lugano
# 81   10312         4170          111376.0  US Boulogne Cote D'Opale
# 257  43041         8388             477.0               CD Numancia
# 176  27780        10218            1971.0                 Excelsior
# 168  26559         8614          100646.0          Sparta Rotterdam
# 149  22805         6269          112225.0                    Novara
# 285  49116         6493            1714.0             AC Bellinzona
# 288  49119         9930             434.0                  FC Aarau
# 131  20520         8690             203.0           Reggio Calabria
# 170  26561         6601               NaN               FC Volendam
# 47    4234         8191            1796.0                   Burnley
# 19    1034         9989             239.0                 Lierse SK
# 12      13         9999             546.0             KSV Roeselare
# 175  27168         9839          100651.0                 VVV-Venlo
# 273  43804         9867             260.0               CD Tenerife
# 160  26551         8525            1907.0                 Willem II
# 163  26554         8526             635.0             De Graafschap
# 63              LEH     4769.0        0.894737   -0.894737        0.684211
# 121             PAD     7809.0        1.235294   -0.588235        0.588235
# 119             GRF     7809.0        0.588235   -1.529412        0.941176
# 154             FRO    10257.0        0.947368   -0.421053        0.894737
# 247             DUN    19694.0        1.157895   -1.157895        0.947368
# 55              CAR     1729.0        1.052632   -0.789474        0.631579
# 230             PEN    17642.0        1.000000   -1.176471        0.705882
# 282             COR    21518.0        0.631579   -1.105263        0.526316
# 14              TUB        1.0        1.294118   -0.647059        0.764706
# 82              ARL     4769.0        0.736842   -0.894737        0.368421
# 150             PES    10257.0        0.789474   -1.421053        0.631579
# 180             DOR    13274.0        0.882353   -1.117647        0.529412
#
#      ratio_away  goal_rate     ratio
# 111   -0.735294   1.058824 -0.691176
# 110   -1.176471   0.882353 -0.705882
# 20    -1.000000   0.933333 -0.733333
# 225   -1.066667   0.900000 -0.733333
# 147   -1.054545   0.890909 -0.736364
# 50    -1.175439   1.008772 -0.736842
# 271   -1.000000   1.000000 -0.736842
# 46    -0.929825   1.035088 -0.754386
# 37    -1.368421   0.736842 -0.763158
# 189   -0.900000   0.833333 -0.766667
# 91    -1.263158   0.815789 -0.789474
# 53    -1.052632   1.131579 -0.789474
# 297   -1.245283   0.933962 -0.792453
# 104   -1.000000   0.852941 -0.794118
# 106   -1.117647   0.882353 -0.794118
# 179   -1.176471   1.088235 -0.794118
# 298   -1.277778   1.277778 -0.805556
# 81    -1.000000   0.815789 -0.815789
# 257   -1.684211   1.000000 -0.815789
# 176   -1.088235   1.132353 -0.816176
# 168   -1.617647   1.117647 -0.823529
# 149   -1.222222   0.944444 -0.833333
# 285   -1.240741   1.185185 -0.833333
# 288   -1.263889   1.062500 -0.840278
# 131   -1.473684   0.789474 -0.842105
# 170   -1.705882   1.117647 -0.852941
# 47    -1.394737   0.921053 -0.855263
# 19    -1.476190   0.896825 -0.865079
# 12    -1.193548   1.000000 -0.887097
# 175   -1.426471   1.117647 -0.889706
# 273   -1.631579   1.052632 -0.894737
# 160   -1.284314   1.088235 -0.897059
# 163   -1.294118   0.955882 -0.911765
# 120   -1.470588   0.852941 -0.911765
# 145   -1.473684   0.868421 -0.947368
# 89    -1.342105   0.934211 -0.960526
# 291   -1.333333   0.925926 -0.962963
# 116   -1.117647   1.029412 -0.970588
# 63    -1.052632   0.789474 -0.973684
# 121   -1.411765   0.911765 -1.000000
# 119   -0.470588   0.764706 -1.000000
# 154   -1.736842   0.921053 -1.078947
# 247   -1.052632   1.052632 -1.105263
# 55    -1.421053   0.842105 -1.105263
# 230   -1.176471   0.852941 -1.176471
# 282   -1.315789   0.578947 -1.210526
# 14    -1.823529   1.029412 -1.235294
# 82    -1.684211   0.552632 -1.289474
# 150   -1.578947   0.710526 -1.500000
# 180   -1.941176   0.705882 -1.529412

# %% [markdown]
# On voit clairement que les équipes ayant le meilleur ratio sont celles qu'on espérait voir telles que le FC Barcelona, le Real Madrid et le Bayern de munich

# %%
match_stat=match.copy()
match_stat=match_stat.loc[match_stat["date"]>="2015"]

#fonction qui renvoie la liste des données des équipes à domicile et en extérieur pour un match
#et les données de leurs joueurs associées
def getsetplayers(matchSet):

    liste=[]
    
    ateam=team_attributes.loc[team_attributes["team_api_id"]==matchSet["away_team_api_id"]].loc[team_attributes["date"]<=matchSet["date"]].mean()
    hteam=team_attributes.loc[team_attributes["team_api_id"]==matchSet["home_team_api_id"]].loc[team_attributes["date"]<=matchSet["date"]].mean()
    
    if(ateam.isnull().any().any() or hteam.isnull().any().any()):
        return False

    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["home_player_1"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])

    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["home_player_2"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])

    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["home_player_3"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])

    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["home_player_4"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])

    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["home_player_5"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])
    
    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["home_player_6"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])
    
    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["home_player_7"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])
    
    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["home_player_8"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])
    
    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["home_player_9"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])
    
    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["home_player_10"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])
    
    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["home_player_11"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])
    
    liste.append(hteam.loc["buildUpPlaySpeed"])
    liste.append(hteam.loc["buildUpPlayDribbling"])
    liste.append(hteam.loc["buildUpPlayPassing"])
    liste.append(hteam.loc["chanceCreationPassing"])
    liste.append(hteam.loc["chanceCreationCrossing"])
    liste.append(hteam.loc["chanceCreationShooting"])
    liste.append(hteam.loc["defencePressure"])
    liste.append(hteam.loc["defenceAggression"])
    liste.append(hteam.loc["defenceTeamWidth"])
    


    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["away_player_1"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])

    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["away_player_2"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])
    
    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["away_player_3"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])

    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["away_player_4"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])

    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["away_player_5"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])

    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["away_player_6"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])
    
    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["away_player_7"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])
    
    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["away_player_8"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])

    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["away_player_9"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])

    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["away_player_10"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])
    
    player=player_attributes.loc[player_attributes["player_api_id"]==matchSet["away_player_11"]].loc[player_attributes["date"]<=matchSet["date"]].mean()
    if(player.isnull().any().any()):
        return False
    liste.append(player.loc["overall_rating"])
    liste.append(player.loc["potential"])
    
    liste.append(ateam.loc["buildUpPlaySpeed"])
    liste.append(ateam.loc["buildUpPlayDribbling"])
    liste.append(ateam.loc["buildUpPlayPassing"])
    liste.append(ateam.loc["chanceCreationPassing"])
    liste.append(ateam.loc["chanceCreationCrossing"])
    liste.append(ateam.loc["chanceCreationShooting"])
    liste.append(ateam.loc["defencePressure"])
    liste.append(ateam.loc["defenceAggression"])
    liste.append(ateam.loc["defenceTeamWidth"])
    
        
    return liste

# %%
#fonction qui renvoie la liste des données des équipes à domicile et en extérieur pour un match
def getset(matchSet):
    
    liste=[]
    
    ateam=team_attributes.loc[team_attributes["team_api_id"]==matchSet["away_team_api_id"]].loc[team_attributes["date"]<=matchSet["date"]].max()
    hteam=team_attributes.loc[team_attributes["team_api_id"]==matchSet["home_team_api_id"]].loc[team_attributes["date"]<=matchSet["date"]].max()
    
    if(ateam.isnull().any().any() or hteam.isnull().any().any()):
        return False

    
    liste.append(hteam.loc["buildUpPlaySpeed"])
    liste.append(hteam.loc["buildUpPlayDribbling"])
    liste.append(hteam.loc["buildUpPlayPassing"])
    liste.append(hteam.loc["chanceCreationPassing"])
    liste.append(hteam.loc["chanceCreationCrossing"])
    liste.append(hteam.loc["chanceCreationShooting"])
    liste.append(hteam.loc["defencePressure"])
    liste.append(hteam.loc["defenceAggression"])
    liste.append(hteam.loc["defenceTeamWidth"])
    

    
    liste.append(ateam.loc["buildUpPlaySpeed"])
    liste.append(ateam.loc["buildUpPlayDribbling"])
    liste.append(ateam.loc["buildUpPlayPassing"])
    liste.append(ateam.loc["chanceCreationPassing"])
    liste.append(ateam.loc["chanceCreationCrossing"])
    liste.append(ateam.loc["chanceCreationShooting"])
    liste.append(ateam.loc["defencePressure"])
    liste.append(ateam.loc["defenceAggression"])
    liste.append(ateam.loc["defenceTeamWidth"])
    
    return liste

# %%
def add_row(matchSet, labeledset):
    
    liste = getsetplayers(matchSet)
    if(liste==False):
        return False
    

    if(matchSet["home_team_goal"]>matchSet["away_team_goal"]):
        labeledset.addExample(liste,1)
    elif(matchSet["home_team_goal"]<matchSet["away_team_goal"]):
        labeledset.addExample(liste,-1)
    else:
        labeledset.addExample(liste,0)
        

    return True

# %% [markdown]
# les données à entrer dans un labeledset

# %%
#Fonction qui permet la création d'un labeledset de dimension 62
def matchToLabeledset(nb_data ,match):
    
    k=0
    train=LabeledSet(62)

    nb_away=0
    nb_home=0
    nb_draw=0
    
    getClassSet(nb_data, "home", match, train)
    getClassSet(nb_data, "away", match, train)
    getClassSet(nb_data, "draw", match, train)
    

    
    return train

# %%
#Fonction qui permet d'ajouter nb tuples de données pour chaque classe de match (home, away, draw)
#à un labeledset
def getClassSet(nb, classe, match, labeledset):
    
    nbclass=0
    
    for i in match.index:

        if(nb<nbclass):
            break
        matchSet=match.loc[i]
        if(classe=="home"):
            if(matchSet["home_team_goal"]>matchSet["away_team_goal"]):
                if(add_row(matchSet, labeledset)):
                    nbclass+=1
        if(classe=="away"):
            if(matchSet["home_team_goal"]<matchSet["away_team_goal"]):
                if(add_row(matchSet, labeledset)):
                    nbclass+=1
        if(classe=="draw"):
            if(matchSet["home_team_goal"]==matchSet["away_team_goal"]):
                if(add_row(matchSet, labeledset)):
                    nbclass+=1

# %% [markdown]
# ## Partie 3 - Code

# %%
from perceptron import LabeledSet
from perceptron import Classifier

#création d'un labeledset de train et d'un labeledset de test
matchset_train = matchToLabeledset(50, match)
matchset_test = matchToLabeledset(50, match_stat)

# %% [markdown]
# Nous avons 3 classes de match: (-1) si l'équipe en extérieur gagne, (1) si l'équipe à domicile gagne et (0) si c'est un match nul.
# On décide de ne pas prendre en compte les match nul dans le classifier de type perceptron car le perceptron est un classifier binaire et l'ajout d'une 3eme classe "0" pour match nul induit beaucoup d'erreur de prédiction. On se base donc seulement sur les victoires et les défaites pour identifier le mieux possible les ecarts entre les classe.

# %%
from perceptron import Perceptron

percepmatch=Perceptron(62,0.1,1000)
percepmatch.train(matchset_train)  
percepmatch.accuracy(matchset_test)
# Out:
# 0.49019607843137253

# %%
from perceptron import KNN

knnmatch=KNN(62,3)
knnmatch.train(matchset_train)  
knnmatch.accuracy(matchset_test)
# Out:
# 0.5751633986928104

# %%
from perceptron import ClassifierBaggingPerceptron

bagPerc = ClassifierBaggingPerceptron(62, 30, 0.3, True)
bagPerc.train(matchset_train)
print("Accuracy Out of Bags: ",1.0-bagPerc.outOfBagsError())
print("Accuracy: ",bagPerc.accuracy(matchset_test))
# Out:
# Accuracy Out of Bags:  1.0
# Accuracy:  0.5032679738562091

# %%
from perceptron import ClassifierBaggingKNN

bagKnn = ClassifierBaggingKNN(62, 30, 0.3, True)
bagKnn.train(matchset_train)
print("Accuracy Out of Bags: ",1.0-bagKnn.outOfBagsError())
print("Accuracy: ",bagKnn.accuracy(matchset_test))
# Out:
# Accuracy Out of Bags:  0.33333333333333337
# Accuracy:  0.42483660130718953

# %%
from perceptron import ClassifierMatch

classMatch = ClassifierMatch(62)
classMatch.train(matchset_train)

acc=classMatch.accuracy(matchset_test)
print("Accuracy globale: ",acc)
# Out:
# home win vs away (home win chance: 0.48166666666666663, away win chance: 0.35333333333333333, draw chance:0.16500000000000004)
# 0.46405228758169936

# %%
match_stat_bca=match.loc[match["home_team_api_id"]==8634]

matchset_bca = matchToLabeledset(50, match_stat_bca)

acc_perc=baggPerc.accuracy(matchset_bca)
acc_knn=baggKNN.accuracy(matchset_bca)
acc=classMatch.accuracy(matchset_bca)

print("Accuracy bagging perceptron du FC Barcelona: ",acc_perc)
print("Accuracy bagging knn du FC Barcelona: ",acc_knn)
print("Accuracy du FC Barcelona: ",acc)
# Out:
# home win vs away (home win chance: 0.44166666666666665, away win chance: 0.3883333333333333, draw chance:0.17000000000000004)
# home win vs away (home win chance: 0.5183333333333333, away win chance: 0.2933333333333334, draw chance:0.18833333333333324)
# home win vs away (home win chance: 0.5316666666666666, away win chance: 0.28, draw chance:0.18833333333333335)
# away win vs home (home win chance: 0.38333333333333336, away win chance: 0.45833333333333337, draw chance:0.15833333333333321)
# home win vs away (home win chance: 0.44333333333333336, away win chance: 0.38, draw chance:0.17666666666666664)
# home win vs away (home win chance: 0.5233333333333333, away win chance: 0.2816666666666667, draw chance:0.19500000000000006)
# home win vs away (home win chance: 0.515, away win chance: 0.2933333333333334, draw chance:0.19166666666666665)
# away win vs home (home win chance: 0.365, away win chance: 0.47000000000000003, draw chance:0.16500000000000004)
# home win vs away (home win chance: 0.5283333333333333, away win chance: 0.2733333333333334, draw chance:0.19833333333333325)
# home win vs away (home win chance: 0.41500000000000004, away win chance: 0.40499999999999997, draw chance:0.17999999999999994)
# home win vs away (home win chance: 0.43500000000000005, away win chance: 0.385, draw chance:0.17999999999999994)
# home win vs away (home win chance: 0.46666666666666673, away win chance: 0.36333333333333334, draw chance:0.16999999999999993)
# home win vs away (home win chance: 0.5683333333333334, away win chance: 0.23666666666666672, draw chance:0.19499999999999995)
# away win vs home (home win chance: 0.3866666666666667, away win chance: 0.42333333333333334, draw chance:0.18999999999999995)
# home win vs away (home win chance: 0.45500000000000007, away win chance: 0.3566666666666667, draw chance:0.18833333333333324)
# home win vs away (home win chance: 0.5366666666666666, away win chance: 0.28166666666666673, draw chance:0.18166666666666664)
# home win vs away (home win chance: 0.47333333333333333, away win chance: 0.3466666666666667, draw chance:0.17999999999999994)
# away win vs home (home win chance: 0.40166666666666667, away win chance: 0.41833333333333333, draw chance:0.17999999999999994)
# away win vs home (home win chance: 0.36666666666666664, away win chance: 0.445, draw chance:0.18833333333333335)
# home win vs away (home win chance: 0.42000000000000004, away win chance: 0.41333333333333333, draw chance:0.16666666666666663)
# home win vs away (home win chance: 0.5216666666666666, away win chance: 0.2933333333333334, draw chance:0.18500000000000005)
# home win vs away (home win chance: 0.42, away win chance: 0.3983333333333333, draw chance:0.18166666666666664)
# home win vs away (home win chance: 0.5216666666666667, away win chance: 0.2916666666666667, draw chance:0.18666666666666654)
# home win vs away (home win chance: 0.5116666666666666, away win chance: 0.29833333333333334, draw chance:0.19000000000000006)
# home win vs away (home win chance: 0.5833333333333334, away win chance: 0.22999999999999998, draw chance:0.18666666666666665)
# home win vs away (home win chance: 0.45833333333333337, away win chance: 0.3416666666666667, draw chance:0.19999999999999996)
# home win vs away (home win chance: 0.5383333333333333, away win chance: 0.26833333333333337, draw chance:0.19333333333333336)
# home win vs away (home win chance: 0.5083333333333333, away win chance: 0.3066666666666667, draw chance:0.18500000000000005)
# home win vs away (home win chance: 0.48166666666666663, away win chance: 0.33166666666666667, draw chance:0.18666666666666676)
# away win vs home (home win chance: 0.365, away win chance: 0.4650000000000001, draw chance:0.16999999999999993)
# away win vs home (home win chance: 0.3833333333333333, away win chance: 0.435, draw chance:0.18166666666666664)
# home win vs away (home win chance: 0.48, away win chance: 0.3383333333333334, draw chance:0.18166666666666664)
# home win vs away (home win chance: 0.495, away win chance: 0.31333333333333335, draw chance:0.19166666666666665)
# 0.7272727272727273

# %%
match_stat_metz=match.loc[match["home_team_api_id"]==8550]

matchset_metz = matchToLabeledset(50, match_stat_metz)

acc_perc=baggPerc.accuracy(matchset_metz)
acc_knn=baggKNN.accuracy(matchset_metz)
acc=classMatch.accuracy(matchset_metz)

print("Accuracy bagging perceptron du FC Barcelona: ",acc_perc)
print("Accuracy bagging knn du FC Barcelona: ",acc_knn)
print("Accuracy du FC Barcelona: ",acc)
# Out:
# away win vs home (home win chance: 0.32, away win chance: 0.4933333333333333, draw chance:0.18666666666666676)
# away win vs home (home win chance: 0.3666666666666667, away win chance: 0.41999999999999993, draw chance:0.21333333333333337)
# away win vs home (home win chance: 0.29833333333333334, away win chance: 0.48, draw chance:0.22166666666666668)
# away win vs home (home win chance: 0.245, away win chance: 0.525, draw chance:0.22999999999999998)
# away win vs home (home win chance: 0.29666666666666663, away win chance: 0.4866666666666667, draw chance:0.21666666666666667)
# away win vs home (home win chance: 0.15499999999999997, away win chance: 0.7100000000000001, draw chance:0.135)
# away win vs home (home win chance: 0.26166666666666666, away win chance: 0.5683333333333334, draw chance:0.16999999999999993)
# away win vs home (home win chance: 0.2716666666666666, away win chance: 0.5033333333333333, draw chance:0.2250000000000001)
# away win vs home (home win chance: 0.2866666666666667, away win chance: 0.4850000000000001, draw chance:0.22833333333333328)
# away win vs home (home win chance: 0.23500000000000004, away win chance: 0.5650000000000001, draw chance:0.19999999999999996)
# away win vs home (home win chance: 0.21833333333333332, away win chance: 0.6283333333333334, draw chance:0.15333333333333332)
# away win vs home (home win chance: 0.15999999999999998, away win chance: 0.7166666666666668, draw chance:0.1233333333333333)
# away win vs home (home win chance: 0.3333333333333333, away win chance: 0.4933333333333333, draw chance:0.17333333333333334)
# away win vs home (home win chance: 0.2033333333333333, away win chance: 0.6316666666666668, draw chance:0.1649999999999998)
# away win vs home (home win chance: 0.2849999999999999, away win chance: 0.5783333333333334, draw chance:0.13666666666666671)
# away win vs home (home win chance: 0.24166666666666667, away win chance: 0.5900000000000001, draw chance:0.16833333333333322)
# Accuracy du FC Metz:  0.5625

# %% [markdown]
# ## Partie 4 - Protocole expérimental

# %% [markdown]
# ## Partie 5 - Résultats

# %% [markdown]
# ## Partie 6 - Analyse
